# %%
import pandas as pd
from pycaret.classification import *

# %%
train = pd.DataFrame()
test = pd.DataFrame()

# %%
import random

# %%
tree_depth = []
nb_var = []
nb_loops = []
nb_nested_loops = []
nb_leaf = []
algo_vec = []
algo = [0,0,0,0,1,2,3]

for _ in range(10000):
    depth = random.randint(1,200)
    loops = random.randint(0, depth)
    var = random.randint(0, depth)
    nested_loops = random.randint(0, loops)
    leaf = random.randint(depth, depth*4)
    algo_sample = random.randint(1, 210)
    
    tree_depth.append(depth)
    nb_var.append(var)
    nb_loops.append(loops)
    nb_nested_loops.append(nested_loops)
    nb_leaf.append(leaf)
    algo_vec.append(algo_sample)

# %%
train["tree_depth"] = tree_depth
train["nb_var"] = nb_var
train["nb_loops"] = nb_loops
train["nb_nested_loops"] = nb_nested_loops
train["nb_leaf"] = nb_leaf
train["algo_vec"] = algo_vec

# %%
tree_depth = []
nb_var = []
nb_loops = []
nb_nested_loops = []
nb_leaf = []
algo_vec = []
algo = [0,0,0,0,1,2,3]

for _ in range(10000):
    depth = random.randint(1,200)
    loops = random.randint(0, depth)
    var = random.randint(0, depth)
    nested_loops = random.randint(0, loops)
    leaf = random.randint(depth, depth*4)
    algo_sample = random.randint(1, 210)
    
    tree_depth.append(depth)
    nb_var.append(var)
    nb_loops.append(loops)
    nb_nested_loops.append(nested_loops)
    nb_leaf.append(leaf)
    algo_vec.append(algo_sample)

# %%
test["tree_depth"] = tree_depth
test["nb_var"] = nb_var
test["nb_loops"] = nb_loops
test["nb_nested_loops"] = nb_nested_loops
test["nb_leaf"] = nb_leaf
test["algo_vec"] = algo_vec

# %%
train
# Out:
#       tree_depth  nb_var  nb_loops  nb_nested_loops  nb_leaf  algo_vec
# 0            115     111        70               57      264        93
# 1            146     108        73               71      238       144
# 2             38       5        24               24       85        78
# 3             55      46        17                7      112        23
# 4             67      59        52               33      129       150
# ...          ...     ...       ...              ...      ...       ...
# 9995         153     149        55                3      407       114
# 9996         180      14        34               12      388        99
# 9997         143     122       122               57      225       119
# 9998         102      38        37               29      175        23
# 9999         139      12        89               59      452       151
#
# [10000 rows x 6 columns]

# %% [markdown]
# ## Dataframes are built

# %%
s = setup(train, target = 'algo_vec')
# Out:
# <style type="text/css">
# #T_56b03_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_56b03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_56b03_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_56b03_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_56b03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_56b03_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_56b03_row0_col1" class="data row0 col1" >5852</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_56b03_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_56b03_row1_col1" class="data row1 col1" >algo_vec</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_56b03_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_56b03_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_56b03_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_56b03_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_56b03_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_56b03_row4_col1" class="data row4 col1" >(10000, 6)</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_56b03_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_56b03_row5_col1" class="data row5 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_56b03_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_56b03_row6_col1" class="data row6 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_56b03_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_56b03_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_56b03_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_56b03_row8_col1" class="data row8 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_56b03_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_56b03_row9_col1" class="data row9 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_56b03_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_56b03_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_56b03_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_56b03_row11_col1" class="data row11 col1" >(6999, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_56b03_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_56b03_row12_col1" class="data row12 col1" >(3001, 5)</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_56b03_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_56b03_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_56b03_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_56b03_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_56b03_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_56b03_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_56b03_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_56b03_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_56b03_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_56b03_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_56b03_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_56b03_row18_col1" class="data row18 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_56b03_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_56b03_row19_col1" class="data row19 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_56b03_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_56b03_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_56b03_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_56b03_row21_col1" class="data row21 col1" >8282</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_56b03_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_56b03_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_56b03_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_56b03_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_56b03_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_56b03_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_56b03_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_56b03_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_56b03_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_56b03_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_56b03_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_56b03_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_56b03_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_56b03_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_56b03_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_56b03_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_56b03_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_56b03_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_56b03_row30_col1" class="data row30 col1" >N

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_914a1 th {
#   text-align: left;
# }
# #T_914a1_row0_col0, #T_914a1_row0_col2, #T_914a1_row1_col0, #T_914a1_row1_col1, #T_914a1_row1_col2, #T_914a1_row1_col3, #T_914a1_row1_col4, #T_914a1_row1_col5, #T_914a1_row1_col6, #T_914a1_row1_col7, #T_914a1_row2_col0, #T_914a1_row2_col1, #T_914a1_row2_col2, #T_914a1_row2_col3, #T_914a1_row2_col4, #T_914a1_row2_col5, #T_914a1_row2_col6, #T_914a1_row2_col7, #T_914a1_row3_col0, #T_914a1_row3_col1, #T_914a1_row3_col2, #T_914a1_row3_col3, #T_914a1_row3_col4, #T_914a1_row3_col5, #T_914a1_row3_col6, #T_914a1_row3_col7, #T_914a1_row4_col0, #T_914a1_row4_col1, #T_914a1_row4_col2, #T_914a1_row4_col3, #T_914a1_row4_col4, #T_914a1_row4_col5, #T_914a1_row4_col6, #T_914a1_row4_col7, #T_914a1_row5_col0, #T_914a1_row5_col1, #T_914a1_row5_col2, #T_914a1_row5_col3, #T_914a1_row5_col4, #T_914a1_row5_col5, #T_914a1_row5_col6, #T_914a1_row5_col7, #T_914a1_row6_col0, #T_914a1_row6_col1, #T_914a1_row6_col3, #T_914a1_row6_col4, #T_914a1_row6_col5, #T_914a1_row6_col6, #T_914a1_row6_col7, #T_914a1_row7_col0, #T_914a1_row7_col1, #T_914a1_row7_col2, #T_914a1_row7_col3, #T_914a1_row7_col4, #T_914a1_row7_col5, #T_914a1_row7_col6, #T_914a1_row7_col7, #T_914a1_row8_col0, #T_914a1_row8_col1, #T_914a1_row8_col2, #T_914a1_row8_col3, #T_914a1_row8_col4, #T_914a1_row8_col5, #T_914a1_row8_col6, #T_914a1_row8_col7, #T_914a1_row9_col0, #T_914a1_row9_col1, #T_914a1_row9_col2, #T_914a1_row9_col3, #T_914a1_row9_col4, #T_914a1_row9_col5, #T_914a1_row9_col6, #T_914a1_row9_col7, #T_914a1_row10_col0, #T_914a1_row10_col1, #T_914a1_row10_col2, #T_914a1_row10_col3, #T_914a1_row10_col4, #T_914a1_row10_col5, #T_914a1_row10_col6, #T_914a1_row10_col7, #T_914a1_row11_col0, #T_914a1_row11_col1, #T_914a1_row11_col2, #T_914a1_row11_col3, #T_914a1_row11_col4, #T_914a1_row11_col5, #T_914a1_row11_col6, #T_914a1_row11_col7, #T_914a1_row12_col0, #T_914a1_row12_col1, #T_914a1_row12_col2, #T_914a1_row12_col3, #T_914a1_row12_col4, #T_914a1_row12_col5, #T_914a1_row12_col6, #T_914a1_row12_col7, #T_914a1_row13_col0, #T_914a1_row13_col1, #T_914a1_row13_col2, #T_914a1_row13_col3, #T_914a1_row13_col4, #T_914a1_row13_col5, #T_914a1_row13_col6, #T_914a1_row13_col7 {
#   text-align: left;
# }
# #T_914a1_row0_col1, #T_914a1_row0_col3, #T_914a1_row0_col4, #T_914a1_row0_col5, #T_914a1_row0_col6, #T_914a1_row0_col7, #T_914a1_row6_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_914a1_row0_col8, #T_914a1_row1_col8, #T_914a1_row2_col8, #T_914a1_row4_col8, #T_914a1_row5_col8, #T_914a1_row6_col8, #T_914a1_row7_col8, #T_914a1_row8_col8, #T_914a1_row9_col8, #T_914a1_row10_col8, #T_914a1_row11_col8, #T_914a1_row12_col8, #T_914a1_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_914a1_row3_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_914a1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_914a1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_914a1_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_914a1_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_914a1_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_914a1_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_914a1_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_914a1_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_914a1_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_914a1_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_914a1_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_914a1_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_914a1_row0_col1" class="data row0 col1" >0.0077</td>
#       <td id="T_914a1_row0_col2" class="data row0 col2" >0.5054</td>
#       <td id="T_914a1_row0_col3" class="data row0 col3" >0.0075</td>
#       <td id="T_914a1_row0_col4" class="data row0 col4" >0.0077</td>
#       <td id="T_914a1_row0_col5" class="data row0 col5" >0.0070</td>
#       <td id="T_914a1_row0_col6" class="data row0 col6" >0.0027</td>
#       <td id="T_914a1_row0_col7" class="data row0 col7" >0.0027</td>
#       <td id="T_914a1_row0_col8" class="data row0 col8" >15.8510</td>
#     </tr>
#     <tr>
#       <th id="T_914a1_level0_row1" class="row_heading level0 row1" >dummy</th>
#       <td id="T_914a1_row1_col0" class="data row1 col0" >Dummy Classifier</td>
#       <td id="T_914a1_row1_col1" class="data row1 col1" >0.0073</td>
#       <td id="T_914a1_row1_col2" class="data row1 col2" >0.5000</td>
#       <td id="T_914a1_row1_col3" class="data row1 col3" >0.0048</td>
#       <td id="T_914a1_row1_col4" class="data row1 col4" >0.0001</td>
#       <td id="T_914a1_row1_col5" class="data row1 col5" >0.0001</td>
#       <td id="T_914a1_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_914a1_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_914a1_row1_col8" class="data row1 col8" >0.0660</td>
#     </tr>
#     <tr>
#       <th id="T_914a1_level0_row2" class="row_heading level0 row2" >dt</th>
#       <td id="T_914a1_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#       <td id="T_914a1_row2_col1" class="data row2 col1" >0.0071</td>
#       <td id="T_914a1_row2_col2" class="data row2 col2" >0.5011</td>
#       <td id="T_914a1_row2_col3" class="data row2 col3" >0.0070</td>
#       <td id="T_914a1_row2_col4" class="data row2 col4" >0.0068</td>
#       <td id="T_914a1_row2_col5" class="data row2 col5" >0.0066</td>
#       <td id="T_914a1_row2_col6" class="data row2 col6" >0.0022</td>
#       <td id="T_914a1_row2_col7" class="data row2 col7" >0.0022</td>
#       <td id="T_914a1_row2_col8" class="data row2 col8" >0.2080</td>
#     </tr>
#     <tr>
#       <th id="T_914a1_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_914a1_row3_col0" class="data row3 col0" >Ridge Classifier</td>
#       <td id="T_914a1_row3_col1" class="data row3 col1" >0.0063</td>
#       <td id="T_914a1_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_914a1_row3_col3" class="data row3 col3" >0.0052</td>
#       <td id="T_914a1_row3_col4" class="data row3 col4" >0.0013</td>
#       <td id="T_914a1_row3_col5" class="data row3 col5" >0.0017</td>
#       <td id="T_914a1_row3_col6" class="data row3 col6" >0.0002</td>
#       <td id="T_914a1_row3_col7" class="data row3 col7" >0.0002</td>
#       <td id="T_914a1_row3_col8" class="data row3 col8" >0.0330</td>
#     </tr>
#     <tr>
#       <th id="T_914a1_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_914a1_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_914a1_row4_col1" class="data row4 col1" >0.0057</td>
#       <td id="T_914a1_row4_col2" class="data row4 col2" >0.5008</td>
#       <td id="T_914a1_row4_col3" class="data row4 col3" >0.0047</td>
#       <td id="T_914a1_row4_col4" class="data row4 col4" >0.0015</td>
#       <td id="T_914a1_row4_col5" class="data row4 col5" >0.0016</td>
#       <td id="T_914a1_row4_col6" class="data row4 col6" >-0.0003</td>
#       <td id="T_914a1_row4_col7" class="data row4 col7" >-0.0003</td>
#       <td id="T_914a1_row4_col8" class="data row4 col8" >0.2700</td>
#     </tr>
#     <tr>
#       <th id="T_914a1_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_914a1_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_914a1_row5_col1" class="data row5 col1" >0.0057</td>
#       <td id="T_914a1_row5_col2" class="data row5 col2" >0.5033</td>
#       <td id="T_914a1_row5_col3" class="data row5 col3" >0.0057</td>
#       <td id="T_914a1_row5_col4" class="data row5 col4" >0.0060</td>
#       <td id="T_914a1_row5_col5" class="data row5 col5" >0.0054</td>
#       <td id="T_914a1_row5_col6" class="data row5 col6" >0.0008</td>
#       <td id="T_914a1_row5_col7" class="data row5 col7" >0.0008</td>

# %%
evaluate_model(best)
