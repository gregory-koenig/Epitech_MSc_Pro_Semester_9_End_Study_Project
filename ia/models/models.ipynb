# %%
import pandas as pd
from pycaret.classification import *

# %%
train = pd.DataFrame()
test = pd.DataFrame()

# %%
import random
import json

# %%
ast = open("ast.json", "r")
json_ast = json.load(ast)

# %%
ast_str = ""
for line in json_ast["ast_vec"]:
    ast_str += f"{line}, "

ast_str = ast_str [:-2]

print(ast_str)
# Out:
# DECLARATION, BEGINROOT, int, FUNCTION, BEGINFUNCPARAMS, ENDFUNCPARAMS, STARTFUNCBODY, IDENTIFIER, main, ENDFUNCBODY, ENDROOT, BEGINDECLBODY, BEGINEXPR, DECLARATION, BEGINDECLINIT, BEGINROOT, int, ARRAY, IDENTIFIER, arr[NUMBER, 3], ENDROOT, ENDDECLINIT, BEGINDECLBODY, ENDDECLBODY, ENDEXPR, BEGINEXPR, EXPRSTATEMENT, EQUALS, ARRAYSUBSCRIPTION, IDENTIFIER, arr[NUMBER, 0], =NUMBER, 0, ENDEXPR, BEGINEXPR, EXPRSTATEMENT, EQUALS, ARRAYSUBSCRIPTION, IDENTIFIER, arr[NUMBER, 1], =NUMBER, 2, ENDEXPR, BEGINEXPR, EXPRSTATEMENT, EQUALS, ARRAYSUBSCRIPTION, IDENTIFIER, arr[NUMBER, 2], =NUMBER, 4, ENDEXPR, BEGINEXPR, FOR, BEGINFORPARAMS, DECLARATION, BEGINDECLINIT, BEGINROOT, int, IDENTIFIER, i, ENDROOT, ENDDECLINIT, BEGINDECLBODY, ENDDECLBODY, LESSTHENOREQ, IDENTIFIER, i<=DIV, SIZEOFEXPR, PARENTEXPR, ADDROF, IDENTIFIER, arr/SIZEOF, BEGINROOT, int, ENDROOT, INCREMENT, ++IDENTIFIER, i, ENDFORPARAMS, ENDEXPR, BEGINEXPR, EXPRSTATEMENT, FUNCCALL, IDENTIFIER, printf(STRING, 'test\n'), ENDEXPR, BEGINEXPR, R
# ...

# %%
ast_vec = []
tree_depth = []
nb_var = []
nb_loops = []
nb_nested_loops = []
nb_leaf = []
algo_vec = []
algo = [0,0,0,0,1,2,3]

for _ in range(10000):
    depth = random.randint(1,200)
    loops = random.randint(0, depth)
    var = random.randint(0, depth)
    nested_loops = random.randint(0, loops)
    leaf = random.randint(depth, depth*4)
    algo_sample = random.randint(1, 210)
    
    ast_vec.append(ast_str)
    tree_depth.append(depth)
    nb_var.append(var)
    nb_loops.append(loops)
    nb_nested_loops.append(nested_loops)
    nb_leaf.append(leaf)
    algo_vec.append(algo_sample)

# %%
train["ast_vec"] = ast_vec
train["tree_depth"] = tree_depth
train["nb_var"] = nb_var
train["nb_loops"] = nb_loops
train["nb_nested_loops"] = nb_nested_loops
train["nb_leaf"] = nb_leaf
train["algo_vec"] = algo_vec

# %%
tree_depth = []
nb_var = []
nb_loops = []
nb_nested_loops = []
nb_leaf = []
algo_vec = []
algo = [0,0,0,0,1,2,3]

for _ in range(10000):
    depth = random.randint(1,200)
    loops = random.randint(0, depth)
    var = random.randint(0, depth)
    nested_loops = random.randint(0, loops)
    leaf = random.randint(depth, depth*4)
    algo_sample = random.randint(1, 210)
    
    tree_depth.append(depth)
    nb_var.append(var)
    nb_loops.append(loops)
    nb_nested_loops.append(nested_loops)
    nb_leaf.append(leaf)
    algo_vec.append(algo_sample)

# %%
test["ast_vec"] = ast_vec
test["tree_depth"] = tree_depth
test["nb_var"] = nb_var
test["nb_loops"] = nb_loops
test["nb_nested_loops"] = nb_nested_loops
test["nb_leaf"] = nb_leaf
test["algo_vec"] = algo_vec

# %%
train
# Out:
#       tree_depth  nb_var  nb_loops  nb_nested_loops  nb_leaf  algo_vec  \
# 0             39      29        14               13      144       205
# 1            183     169        99               71      497       136
# 2            141     108       128               44      293       209
# 3             77      34        20                5      228       124
# 4             19       8         8                1       41        74
# ...          ...     ...       ...              ...      ...       ...
# 9995         109     100        13                9      218        17
# 9996          70      41        43               38      125        61
# 9997          29      25         0                0      102       170
# 9998         121      49        25               22      180       127
# 9999         119      29       103               95      137        68
#
#                                                 ast_vec
# 0     DECLARATION, BEGINROOT, int, FUNCTION, BEGINFU...
# ...

# %% [markdown]
# ## Dataframes are built

# %%
s = setup(train, target = 'algo_vec')
# Out:
# <style type="text/css">
# #T_1ebb7_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1ebb7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ebb7_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1ebb7_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ebb7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ebb7_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1ebb7_row0_col1" class="data row0 col1" >3497</td>
#     </tr>
#     <tr>
#       <th id="T_1ebb7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ebb7_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1ebb7_row1_col1" class="data row1 col1" >algo_vec</td>
#     </tr>
#     <tr>
#       <th id="T_1ebb7_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_9e14c th {
#   text-align: left;
# }
# ...

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
save_model(best, 'best_pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=[], target='algo_vec',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  fill_value_categorical=None,
#                                  fill_value_numerical=None,
#                                  numeric_str...
#                  ('fix_perfect', Remove_100(target='algo_vec')),
#                  ('clean_names', Clean_Colum_Names()),
# ...

# %%
loaded_model = load_model('my_best_pipeline')
print(loaded_model)
